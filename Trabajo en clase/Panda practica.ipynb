# %%
f=open('') #para modificar archivo de texto txt
texto=f.readlines()

for s in texto:
    cadena=s.replace('\t',',')
    cadena=cadena.replace(',,',',')
    cadena=cadena.replace(',,',',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-d93c1ba2462d> in <module>()
# ----> 1 f=open('') #para modificar archivo de texto txt
#       2 texto=f.readlines()
#       3
#       4 for s in texto:
#       5     cadena=s.replace('\t',',')
#
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %%
import requests

# %%
url='https://www.prensa.com/'
respuesta=requests.get(url)
respuesta.text
# Out:
# '<!DOCTYPE html>\n\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js a-grade" lang="es"> <!--<![endif]--><head>\n\n    <!-- Google Tag Manager -->\n<script>\n    (function (w, d, s, l, i) {\n        w[l] = w[l] || [];\n        w[l].push({\n            \'gtm.start\': new Date().getTime(), event: \'gtm.js\'\n        });\n        var f = d.getElementsByTagName(s)[0],\n            j = d.createElement(s), dl = l != \'dataLayer\' ? \'&l=\' + l : \'\';\n        j.async = true;\n        j.src = \'https://www.googletagmanager.com/gtm.js?id=\' + i + dl;\n        f.parentNode.insertBefore(j, f);\n    })\n    (window, document, \'script\', \'dataLayer\', \'GTM-MT7266Z\');\n</script>\n<!-- End Google Tag Manager -->\n    <link href="/2015/04/08/favicon.ico" rel="shortcut icon" type="image/x-
# ...

# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np

# %%
obj = Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj2 = Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2['b']
# Out:
# 7

# %%
obj2*3
# Out:
# d    12
# b    21
# a   -15
# c     9
# dtype: int64

# %%
'e' in obj2
# Out:
# False

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj3 = Series(sdata)
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
data = {'estado': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada'],
'año': [2000, 2001, 2002, 2001, 2002],
'poblacion': [1.5, 1.7, 3.6, 2.4, 2.9]}

frame = DataFrame(data)
frame
# Out:
#    estado   año  poblacion
# 0    Ohio  2000        1.5
# 1    Ohio  2001        1.7
# 2    Ohio  2002        3.6
# 3  Nevada  2001        2.4
# 4  Nevada  2002        2.9

# %%
DataFrame(data, columns=['año', 'estado', 'poblacion'])
# Out:
#     año  estado  poblacion
# 0  2000    Ohio        1.5
# 1  2001    Ohio        1.7
# 2  2002    Ohio        3.6
# 3  2001  Nevada        2.4
# 4  2002  Nevada        2.9

# %%
frame2 = DataFrame(data, columns=['año', 'estado', 'poblacion', 'deuda'],index=['one', 'two', 'three', 'four', 'five'])
frame2
# Out:
#         año  estado  poblacion deuda
# one    2000    Ohio        1.5   NaN
# two    2001    Ohio        1.7   NaN
# three  2002    Ohio        3.6   NaN
# four   2001  Nevada        2.4   NaN
# five   2002  Nevada        2.9   NaN

# %%
frame2.loc['five']
# Out:
# año            2002
# estado       Nevada
# poblacion       2.9
# deuda           NaN
# Name: five, dtype: object

# %%
frame2['deuda']=[16.5,12.5,9.8,4.9,4.4] #se añadio dates de deuda
frame2
frame2['deuda'].mean() #para realizar un promedio de los datos de deuda
# Out:
# 9.62

# %%
frame2['deuda'].sum() #sumar los datos de deuda
# Out:
# 48.099999999999994

# %%
frame2['west']= np.random.rand(5) #agregar una nueva columna
frame2
# Out:
#         año  estado  poblacion  deuda      west
# one    2000    Ohio        1.5   16.5  0.197356
# two    2001    Ohio        1.7   12.5  0.054772
# three  2002    Ohio        3.6    9.8  0.884248
# four   2001  Nevada        2.4    4.9  0.829349
# five   2002  Nevada        2.9    4.4  0.610702

# %%
frame3=frame2.T
frame3
# Out:
#                 one       two     three      four      five
# año            2000      2001      2002      2001      2002
# estado         Ohio      Ohio      Ohio    Nevada    Nevada
# poblacion       1.5       1.7       3.6       2.4       2.9
# deuda          16.5      12.5       9.8       4.9       4.4
# west       0.197356  0.054772  0.884248  0.829349  0.610702

# %%
obj = Series([4.5, 7.2, -5.3, 3.6], index=['d', 'b', 'a', 'c'])
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
obj2 = obj.reindex(['a', 'b', 'c', 'd', 'e'])
obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
frame2
# Out:
#         año  estado  poblacion  deuda      west
# one    2000    Ohio        1.5   16.5  0.197356
# two    2001    Ohio        1.7   12.5  0.054772
# three  2002    Ohio        3.6    9.8  0.884248
# four   2001  Nevada        2.4    4.9  0.829349
# five   2002  Nevada        2.9    4.4  0.610702

# %%
frame2.drop(['four','two']) #el 4 no se elimina
frame2
# Out:
#         año  estado  poblacion  deuda      west
# one    2000    Ohio        1.5   16.5  0.197356
# two    2001    Ohio        1.7   12.5  0.054772
# three  2002    Ohio        3.6    9.8  0.884248
# four   2001  Nevada        2.4    4.9  0.829349
# five   2002  Nevada        2.9    4.4  0.610702
